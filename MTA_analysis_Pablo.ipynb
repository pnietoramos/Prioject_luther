# %%
import io
import pandas as pd
import requests
from datetime import datetime as dt
import matplotlib.pyplot as plt

# %%
file_url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_180623.txt"
s = requests.get(url).content
turnstiles_df = pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6658725  2257032
# 1  REGULAR  6658747  2257036
# 2  REGULAR  6658766  2257068
# 3  REGULAR  6658866  2257139
# 4  REGULAR  6659043  2257188

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
turnstiles_df.rename(columns={column:column.strip() for column in turnstiles_df.columns}, inplace=True)
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
turnstiles_df["DATE_TIME"] = pd.to_datetime(turnstiles_df.DATE + " " + turnstiles_df.TIME, format="%m/%d/%Y %H:%M:%S")
turnstiles_df.groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/16/2018  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME
# 0  REGULAR  6658725  2257032 2018-06-16 00:00:00
# 1  REGULAR  6658747  2257036 2018-06-16 04:00:00
# 2  REGULAR  6658766  2257068 2018-06-16 08:00:00
# 3  REGULAR  6658866  2257139 2018-06-16 12:00:00
# 4  REGULAR  6659043  2257188 2018-06-16 16:00:00

# %%
plt.scatter(turnstiles_df, turnstiles_df, c="r")
